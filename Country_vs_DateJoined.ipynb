# %% [markdown]
# ## Question Country vs Date Joined
# Do certain geographic regions see a higher concentration of Unicorns joining during specific periods?

# %%
# Import Dependenciews
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
from pathlib import Path

# %%
# Load and read CSV file
csvPath = Path("Resources/merged_df.csv")
mergedDF = pd.read_csv(csvPath, encoding="UTF-8")

# Drop original CSV indexing
mergedDF = mergedDF.drop(columns=['Unnamed: 0'])

# Display
mergedDF.head(10)
# Out:
#         Company 2022_Valuation 2023_Valuation  2024_Valuation Date Joined  \
# 0     ByteDance           $140           $225           225.0    4/7/2017
# 1        SpaceX           $127           $137           150.0   12/1/2012
# 2         SHEIN           $100            $66            66.0    7/3/2018
# 3        Stripe            $95            $50            65.0   1/23/2014
# 4         Canva            $40            $40            25.4    1/8/2018
# 5  Checkout.com            $40            $11            11.0    5/2/2019
# 6     Instacart            $39            $12             NaN  12/30/2014
# 7    Databricks            $38            $31            43.0    2/5/2019
# 8       Revolut            $33            $33            33.0   4/26/2018
# 9    Epic Games         $31.50         $31.50            22.5  10/26/2018
#
#           Country           City                             Industry  \
# 0           China        Beijing              Artificial intelligence
# 1   United States      Hawthorne                                Other
# 2           China       Shenzhen      E-commerce & direct-to-consumer
# 3   United States  San Francisco                              Fintech
# 4       Australia    Surry Hills         Internet software & services
# 5  United Kingdom         London                              Fintech
# 6   United States  San Francisco  Supply chain, logistics, & delivery
# 7   United States  San Francisco          Data management & analytics
# 8  United Kingdom         London                              Fintech
# 9   United States           Cary                                Other
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...
# 5  Tiger Global Management, Insight Partners, DST...
# 6  Khosla Ventures, Kleiner Perkins Caufield & By...
# 7  Andreessen Horowitz, New Enterprise Associates...
# 8         index Ventures, DST Global, Ribbit Capital
# 9              Tencent Holdings, KKR, Smash Ventures

# %%
# Reformat date Joined
mergedDF['Date Joined'] = pd.to_datetime(mergedDF['Date Joined'], format = '%m/%d/%Y')

# Create a sorted DataFrame
sortedMergedDF = pd.DataFrame(mergedDF)

# Sort companies from earliest join date to most recent join date
sortedMergedDF = sortedMergedDF.sort_values(by="Date Joined", ascending = True)

# Display top 10 (earliest joined)
sortedMergedDF.head(10)
# Out:
#                         Company 2022_Valuation 2023_Valuation  2024_Valuation  \
# 725                      Veepee          $1.38          $1.38            1.38
# 125                  Vice Media          $5.70            NaN             NaN
# 105                      Klarna          $6.70          $6.70            6.70
# 447  Trendy Group International             $2             $2            2.00
# 11                     Fanatics            $27            $31           31.00
# 1                        SpaceX           $127           $137          150.00
# 448                       Avant             $2             $2            2.00
# 615                    Mu Sigma          $1.50          $1.50            1.50
# 93                   Automattic          $7.50          $7.50            7.50
# 930                     Lookout             $1             $1            1.00
#
#     Date Joined        Country                   City  \
# 725  2007-07-02         France  La Plaine Saint-Denis
# 125  2011-04-02  United States               Brooklyn
# 105  2011-12-12         Sweden              Stockholm
# 447  2012-02-13      Hong Kong                Kowloon
# 11   2012-06-06  United States           Jacksonville
# 1    2012-12-01  United States              Hawthorne
# 448  2012-12-17  United States                Chicago
# 615  2013-02-07  United States             Northbrook
# 93   2013-05-27  United States          San Francisco
# 930  2013-10-10  United States          San Francisco
#
#                             Industry  \
# 725  E-commerce & direct-to-consumer
# 125     Internet software & services
# 105                          Fintech
# 447                Consumer & retail
# 11   E-commerce & direct-to-consumer
# 1                              Other
# 448          Artificial intelligence
# 615      Data management & analytics
# 93      Internet software & services
# 930                    Cybersecurity
#
#                                       Select Investors
# 725                     Summit Partners, Qatar Holding
# 125  Technology Crossover Ventures, A&E Television ...
# 105  Institutional Venture Partners, Sequoia Capita...
# 447                                 L Capital Partners
# 11   SoftBank Group, Andreessen Horowitz, Temasek H...
# 1    Founders Fund, Draper Fisher Jurvetson, Rothen...
# 448         RRE Ventures, Tiger Global, August Capital
# 615                  Sequoia Capital, General Atlantic
# 93   Insight Venture Partners, Lowercase Capital, P...
# 930  Accel Partners, Greylock Partners, Lowercase C...

# %%
# Isolate the year from date
sortedMergedDF['Year Joined'] = sortedMergedDF['Date Joined'].dt.year

# Group by year and count number of companies joined per year
start_year = 2007
end_year = 2015
intervalOneFilteredDF = sortedMergedDF[(sortedMergedDF['Year Joined'] >= start_year) & (sortedMergedDF['Year Joined'] <= end_year)]
intervalOneFilteredDF
# Out:
#                         Company 2022_Valuation 2023_Valuation  2024_Valuation  \
# 725                      Veepee          $1.38          $1.38            1.38
# 125                  Vice Media          $5.70            NaN             NaN
# 105                      Klarna          $6.70          $6.70            6.70
# 447  Trendy Group International             $2             $2            2.00
# 11                     Fanatics            $27            $31           31.00
# 1                        SpaceX           $127           $137          150.00
# 448                       Avant             $2             $2            2.00
# 615                    Mu Sigma          $1.50          $1.50            1.50
# 93                   Automattic          $7.50          $7.50            7.50
# 930                     Lookout             $1             $1            1.00
# 3                        Stripe            $95            $50           65.00
# 861                     TangoMe          $1.10          $1.10            1.10
# 228       Intarcia Therapeutics          $3.80          $3.80             NaN
# 932                    Snapdeal             $1             $1            1.00
# 933     TechStyle Fashion Group             $1             $1            1.00
# 198                       Houzz             $4             $4            4.00
# 496                  Magic Leap             $2             $2            2.00
# 697                      Koudai          $1.40          $1.40            1.40
# 110                    Ola Cabs          $7.50            NaN             NaN
# 200                Yello Mobile             $4             $4            4.00
# 934                      InMobi             $1             $1            1.00
# 6                     Instacart            $39            $12             NaN
# 935            LinkSure Network             $1             $1            1.00
# 936                Red Ventures             $1             $1            1.00
# 551                  Apus Group          $1.73          $1.73            1.73
# 937                      BeiBei             $1             $1            1.00
# 18              DJI Innovations            $15            $15           15.00
# 938                    Lamabang             $1             $1            1.00
# 449                  Tubatu.com             $2             $2            2.00
# 65                       Tanium             $9             $9            9.00
# 343                     Illumio          $2.75          $2.75            2.75
# 939                     JimuBox             $1            NaN             NaN
# 580                   Infinidat          $1.60          $1.60            1.60
# 577                    Zhubajie          $1.61          $1.61            1.61
# 618                       TuJia          $1.50          $1.50            1.50
# 940                     FXiaoKe             $1             $1             NaN
# 850                   LifeMiles          $1.15          $1.15            1.15
# 737                   Flipboard          $1.32          $1.32            1.32
# 912                     Jiuxian          $1.05          $1.05            1.05
# 941                   Vox Media             $1            NaN             NaN
# 117          Royole Corporation             $6             $6            6.00
# 392                      Carbon          $2.40          $2.40            2.40
# 539                      ZocDoc          $1.80          $1.80            1.80
# 942                     Mia.com             $1             $1            1.00
# 405                 WEMAKEPRICE          $2.34          $2.34             NaN
# 450                   BlaBlaCar             $2             $2            2.00
# 100                   We Doctor             $7             $7            7.00
# 283                   Thumbtack          $3.20          $3.20            3.20
# 862                   AppDirect          $1.10          $1.10            1.10
# 943                   58 Daojia             $1             $1            1.00
# 944                       Womai             $1             $1            1.00
# 408                      Uptake          $2.30          $2.30            2.30
# 945                     HuJiang             $1             $1            1.00
# 946                 iTutorGroup             $1             $1            1.00
# 296                       Yixia             $3             $3            3.00
# 51                        Gusto            $10            $10           10.00
#
#     Date Joined        Country                   City  \
# 725  2007-07-02         France  La Plaine Saint-Denis
# 125  2011-04-02  United States               Brooklyn
# 105  2011-12-12         Sweden              Stockholm
# 447  2012-02-13      Hong Kong                Kowloon
# 11   2012-06-06  United States           Jacksonville
# 1    2012-12-01  United States              Hawthorne
# 448  2012-12-17  United States                Chicago
# 615  2013-02-07  United States             Northbrook
# 93   2013-05-27  United States          San Francisco
# 930  2013-10-10  United States          San Francisco
# 3    2014-01-23  United States          San Francisco
# 861  2014-03-20  United States          Mountain View
# 228  2014-04-01  United States                 Boston
# 932  2014-05-21          India              New Delhi
# 933  2014-08-29  United States             El Segundo
# 198  2014-09-30  United States              Palo Alto
# 496  2014-10-21  United States             Plantation
# 697  2014-10-23          China                Beijing
# 110  2014-10-27          India              Bengaluru
# 200  2014-11-11    South Korea                  Seoul
# 934  2014-12-02          India              Bengaluru
# 6    2014-12-30  United States          San Francisco
# 935  2015-01-01          China               Shanghai
# 936  2015-01-07  United States              Fort Mill
# 551  2015-01-16          China                Beijing
# 937  2015-01-22          China               Hangzhou
# 18   2015-01-23          China               Shenzhen
# 938  2015-03-06          China               Shenzhen
# 449  2015-03-09          China               Shenzhen
# 65   2015-03-31  United States               Kirkland
# 343  2015-04-14  United States              Sunnyvale
# 939  2015-04-21          China                Beijing
# 580  2015-04-29  United States                Waltham
# 577  2015-06-16          China              Chongqing
# 618  2015-06-17          China                Beijing
# 940  2015-07-02          China                Beijing
# 850  2015-07-13       Colombia                 Bogota
# 737  2015-07-22  United States              Palo Alto
# 912  2015-07-30          China                Beijing
# 941  2015-08-12  United States             Washington
# 117  2015-08-18          China               Shenzhen
# 392  2015-08-20  United States           Redwood City
# 539  2015-08-20  United States               New York
# 942  2015-09-08          China                Beijing
# 405  2015-09-09    South Korea                  Seoul
# 450  2015-09-16         France                  Paris
# 100  2015-09-22          China               Hangzhou
# 283  2015-09-29  United States          San Francisco
# 862  2015-10-07  United States          San Francisco
# 943  2015-10-12          China                Beijing
# 944  2015-10-12          China                Beijing
# 408  2015-10-27  United States                Chicago
# 945  2015-10-29          China               Shanghai
# 946  2015-11-18          China               Shanghai
# 296  2015-11-24          China                Beijing
# 51   2015-12-18  United States          San Francisco
#
#                                 Industry  \
# 725      E-commerce & direct-to-consumer
# 125         Internet software & services
# 105                              Fintech
# 447                    Consumer & retail
# 11       E-commerce & direct-to-consumer
# 1                                  Other
# 448              Artificial intelligence
# 615          Data management & analytics
# 93          Internet software & services
# 930                        Cybersecurity
# 3                                Fintech
# 861          Mobile & telecommunications
# 228                               Health
# 932      E-commerce & direct-to-consumer
# 933      E-commerce & direct-to-consumer
# 198      E-commerce & direct-to-consumer
# 496                             Hardware
# 697      E-commerce & direct-to-consumer
# 110                Auto & transportation
# 200          Mobile & telecommunications
# 934          Mobile & telecommunications
# 6    Supply chain, logistics, & delivery
# 935          Mobile & telecommunications
# 936                                Other
# 551          Mobile & telecommunications
# 937      E-commerce & direct-to-consumer
# 18                              Hardware
# 938      E-commerce & direct-to-consumer
# 449      E-commerce & direct-to-consumer
# 65                         Cybersecurity
# 343                        Cybersecurity
# 939                              Fintech
# 580                             Hardware
# 577         Internet software & services
# 618                               Travel
# 940          Mobile & telecommunications
# 850                                Other
# 737         Internet software & services
# 912      E-commerce & direct-to-consumer
# 941         Internet software & services
# 117                             Hardware
# 392                             Hardware
# 539                               Health
# 942      E-commerce & direct-to-consumer
# 405      E-commerce & direct-to-consumer
# 450                Auto & transportation
# 100                               Health
# 283      E-commerce & direct-to-consumer
# 862      E-commerce & direct-to-consumer
# 943         Internet software & services
# 944      E-commerce & direct-to-consumer
# 408              Artificial intelligence
# 945                               Edtech
# 946                               Edtech
# 296          Mobile & telecommunications
# 51                               Fintech
#
#                                       Select Investors  Year Joined
# 725                     Summit Partners, Qatar Holding         2007
# 125  Technology Crossover Ventures, A&E Television ...         2011
# 105  Institutional Venture Partners, Sequoia Capita...         2011
# 447                                 L Capital Partners         2012
# 11   SoftBank Group, Andreessen Horowitz, Temasek H...         2012
# 1    Founders Fund, Draper Fisher Jurvetson, Rothen...         2012
# 448         RRE Ventures, Tiger Global, August Capital         2012
# 615                  Sequoia Capital, General Atlantic         2013
# 93   Insight Venture Partners, Lowercase Capital, P...         2013
# 930  Accel Partners, Greylock Partners, Lowercase C...         2013
# 3          Khosla Ventures, LowercaseCapital, capitalG         2014
# 861  Draper Fisher Jurtson, Qualcomm Ventures, Alib...         2014
# 228  New Enterprise Associates, New Leaf Venture Pa...         2014
# 932            SoftBankGroup, Blackrock, Alibaba Group         2014
# 933    Matrix Partners, Passport Capital, Rho Ventures         2014
# 198  New Enterprise Associates, Sequoia Capital, Co...         2014
# 496  Obvious Ventures, Qualcomm Ventures, Andreesse...         2014
# 697  New Enterprise Associates, Tiger Global manage...         2014
# 110    Accel Partners, SoftBank Group, Sequoia Capital         2014
# 200                                        Formation 8         2014
# 934  Kleiner Perkins Caufield & Byers, Softbank Cor...         2014
# 6    Khosla Ventures, Kleiner Perkins Caufield & By...         2014
# 935                                                NaN         2015
# 936             Silver Lake Partners, General Atlantic         2015
# 551  Redpoint Ventures, QiMing Venture Partners, Ch...         2015
# 937  Banyan Capital, New Horizon Capital, IDG Capit...         2015
# 18                     Accel Partners, Sequoia Capital         2015
# 938            5Y Capital, Matrix Partners China, K2VC         2015
# 449  Sequoia Capital China, Matrix Partners China, ...         2015
# 65     Andreessen Horowitz, Nor-Cal Invest, TPG Growth         2015
# 343  Data Collective, Formation 8, General Catalyst...         2015
# 939  Matrix Partners China, Ventech China, Shunwei ...         2015
# 580                          TPG Growth, Goldman Sachs         2015
# 577                 Cybernaut Growth Fund, IDG Capital         2015
# 618              GGV Capital, QiMing Venture Partnersl         2015
# 940  IDG Capital, Northern Light Venture Capital, D...         2015
# 850                               Advent International         2015
# 737  Kleiner Perkins Caufield & Byers, Comcast Vent...         2015
# 912  Sequoia Capital China, Rich Land Capital, Merr...         2015
# 941  Accel Partners, Comcast Ventures, General Atla...         2015
# 117              Warmsun Holding, IDG Capital Partners         2015
# 392  Google Ventures, Sequoia Capital, Wakefield Group         2015
# 539      Founders Fund, Khosla Ventures, Goldman Sachs         2015
# 942       Sequoia Capital China, ZhenFund, K2 Ventures         2015
# 405                                IMM Investment, NXC         2015
# 450  Accel Partners, Index Ventures, Insight Ventur...         2015
# 100                         Tencent, Morningside Group         2015
# 283      Tiger Global, Sequoia Capital, Google Capital         2015
# 862             Mithril, iNovia Capital, Foundry Group         2015
# 943              KKR, Alibaba Group, Ping An Insurance         2015
# 944            SAIF Partners China, Baidu, IDG Capital         2015
# 408  Revolution, New Enterprise Associates, Caterpi...         2015
# 945     China Minsheng Investment, Baidu, Wanxin Media         2015
# 946  QiMing Venture Partners, Temasek Holdings, Sil...         2015
# 296  Sequoia Capital China, Sina Weibo, Kleiner Per...         2015
# 51   General Catalyst Partners, Google Ventures, Kl...         2015

# %%
intOneDF = intervalOneFilteredDF.groupby('Country').size().reset_index(name='Number of Unicorns')
print(intOneDF)

# Plotting the data
plt.figure(figsize=(10, 7))
plt.barh(intOneDF['Country'], intOneDF['Number of Unicorns'], color='seagreen')
plt.title(f'Number of Unicorn Companies by Country from {start_year} to {end_year}')
plt.xlabel('Number of Unicorns')
plt.ylabel('Country')
plt.grid(axis='x')

# Save plot to file
plt.savefig("output_data/CountryvsDateJoined/Number of Unicorn Companies by Country (2007-2015)")
plt.show()
# Out:
#          Country  Number of Unicorns
# 0          China                  20
# 1       Colombia                   1
# 2         France                   2
# 3      Hong Kong                   1
# 4          India                   3
# 5    South Korea                   2
# 6         Sweden                   1
# 7  United States                  26

# %%
# Group by year and count number of companies joined per year
startYear = 2016
endYear = 2022
intervalTwoFilteredDF = sortedMergedDF[(sortedMergedDF['Year Joined'] >= startYear) & (sortedMergedDF['Year Joined'] <= endYear)]
intervalTwoFilteredDF
# Out:
#                Company 2022_Valuation 2023_Valuation  2024_Valuation  \
# 842       L&P Cosmetic          $1.19          $1.19            1.19
# 947           MindMaze             $1             $1            1.00
# 52           Chehaoduo            $10            $10           10.00
# 14         Xiaohongshu            $20            $20           20.00
# 124            Lianjia          $5.77          $5.77            5.77
# ..                 ...            ...            ...             ...
# 617  Orna Therapeutics          $1.50          $1.50            1.50
# 537           MEGAZONE          $1.83          $1.83            1.83
# 744         Shiprocket          $1.30          $1.30            1.23
# 573  Incredible Health          $1.65          $1.65            1.65
# 350             Tridge          $2.70          $2.70            2.70
#
#     Date Joined        Country           City  \
# 842  2016-01-01    South Korea          Seoul
# 947  2016-01-28    Switzerland       Lausanne
# 52   2016-03-12          China        Beijing
# 14   2016-03-31          China       Shanghai
# 124  2016-04-07          China        Beijing
# ..          ...            ...            ...
# 617  2022-08-16  United States      Cambridge
# 537  2022-08-16    South Korea          Seoul
# 744  2022-08-16          India      New Delhi
# 573  2022-08-17  United States  San Francisco
# 350  2022-08-24    South Korea          Seoul
#
#                             Industry  \
# 842                Consumer & retail
# 947                           Health
# 52   E-commerce & direct-to-consumer
# 14   E-commerce & direct-to-consumer
# 124  E-commerce & direct-to-consumer
# ..                               ...
# 617                           Health
# 537                         Internet
# 744                         Internet
# 573     Internet software & services
# 350     Internet software & services
#
#                                       Select Investors  Year Joined
# 842                                       CDIB Capital         2016
# 947                                      Hinduja Group         2016
# 52                   Sequoia Capital China, GX Capital         2016
# 14                      GGV Capital, ZhenFund, Tencent         2016
# 124                   Tencent, Baidu, Huasheng Capital         2016
# ..                                                 ...          ...
# 617  MPM Capital, Astellas Venture Management, F2 V...         2022
# 537  Salesforce Ventures, ATP Investment, kt invest...         2022
# 744  Bertelsmann India Investments, March Capital P...         2022
# 573         Obvious Ventures, Andreessen Horowitz, NFX         2022
# 350            Forest Partners, Softbank Ventures Asia         2022
#
# [1151 rows x 10 columns]

# %%
intTwoDF = intervalTwoFilteredDF.groupby('Country').size().reset_index(name='Number of Unicorns')

print(intTwoDF)

# Plotting the data
plt.figure(figsize=(25, 7))
# Plotting the data
plt.figure(figsize=(14, 8))  # Increase the figure size
bars = plt.barh(intTwoDF['Country'], intTwoDF['Number of Unicorns'], color='orange')
yTickPosition = range(len(intTwoDF))
# Add data labels
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{bar.get_width()}', 
             va='center', ha='left')
plt.title(f'Number of Unicorn Companies by Country from {startYear} to {endYear}')
plt.xlabel('Number of Unicorns')
plt.ylabel('Country')
plt.yticks(yTickPosition, intTwoDF['Country'], fontsize=9)
plt.grid(axis='x')

# Save plot to file
plt.savefig("output_data/CountryvsDateJoined/Number of Unicorn Companies by Country (2016-2022)")
plt.show()
# Out:
#                  Country  Number of Unicorns
# 0              Argentina                   1
# 1              Australia                   8
# 2                Austria                   2
# 3                Bahamas                   1
# 4                Belgium                   3
# 5                Bermuda                   1
# 6                 Brazil                  17
# 7                 Canada                  19
# 8                  Chile                   2
# 9                  China                 154
# 10              Colombia                   2
# 11               Croatia                   2
# 12        Czech Republic                   1
# 13               Denmark                   2
# 14               Ecuador                   1
# 15               Estonia                   5
# 16               Finland                   4
# 17                France                  22
# 18               Germany                  29
# 19             Hong Kong                   6
# 20                 India                  67
# 21             Indonesia                   7
# 22               Ireland                   6
# 23                Israel                  22
# 24                 Italy                   1
# 25                 Japan                   6
# 26             Lithuania                   2
# 27            Luxembourg                   1
# 28              Malaysia                   1
# 29                Mexico                   8
# 30           Netherlands                   7
# 31               Nigeria                   1
# 32                Norway                   5
# 33           Philippines                   2
# 34               Senegal                   1
# 35            Seychelles                   1
# 36             Singapore                  13
# 37          South Africa                   2
# 38           South Korea                  15
# 39                 Spain                   4
# 40                Sweden                   7
# 41           Switzerland                   6
# 42              Thailand                   2
# 43                Turkey                   3
# 44  United Arab Emirates                   3
# 45        United Kingdom                  46
# 46         United States                 628
# 47               Vietnam                   2

# %%
us_companies = sortedMergedDF[sortedMergedDF['Country'] == 'United States']

us_companies = pd.DataFrame(us_companies)

us_companies
# Out:
#                   Company 2022_Valuation 2023_Valuation  2024_Valuation  \
# 125            Vice Media          $5.70            NaN             NaN
# 11               Fanatics            $27            $31           31.00
# 1                  SpaceX           $127           $137          150.00
# 448                 Avant             $2             $2            2.00
# 615              Mu Sigma          $1.50          $1.50            1.50
# ...                   ...            ...            ...             ...
# 787             ClassDojo          $1.25          $1.25            1.25
# 1206  Unstoppable Domains             $1             $1            1.00
# 926                  Flow             $1             $1            1.00
# 617     Orna Therapeutics          $1.50          $1.50            1.50
# 573     Incredible Health          $1.65          $1.65            1.65
#
#      Date Joined        Country           City  \
# 125   2011-04-02  United States       Brooklyn
# 11    2012-06-06  United States   Jacksonville
# 1     2012-12-01  United States      Hawthorne
# 448   2012-12-17  United States        Chicago
# 615   2013-02-07  United States     Northbrook
# ...          ...            ...            ...
# 787   2022-07-21  United States  San Francisco
# 1206  2022-07-27  United States      Las Vegas
# 926   2022-08-15  United States       New York
# 617   2022-08-16  United States      Cambridge
# 573   2022-08-17  United States  San Francisco
#
#                              Industry  \
# 125      Internet software & services
# 11    E-commerce & direct-to-consumer
# 1                               Other
# 448           Artificial intelligence
# 615       Data management & analytics
# ...                               ...
# 787                            Edtech
# 1206     Internet software & services
# 926                           Fintech
# 617                            Health
# 573      Internet software & services
#
#                                        Select Investors  Year Joined
# 125   Technology Crossover Ventures, A&E Television ...         2011
# 11    SoftBank Group, Andreessen Horowitz, Temasek H...         2012
# 1     Founders Fund, Draper Fisher Jurvetson, Rothen...         2012
# 448          RRE Ventures, Tiger Global, August Capital         2012
# 615                   Sequoia Capital, General Atlantic         2013
# ...                                                 ...          ...
# 787   General Catalyst, Unkork Capital, Tencent Hold...         2022
# 1206              Boost VC, Draper Associates, Gaingels         2022
# 926                                 Andreessen Horowitz         2022
# 617   MPM Capital, Astellas Venture Management, F2 V...         2022
# 573          Obvious Ventures, Andreessen Horowitz, NFX         2022
#
# [654 rows x 10 columns]

# %%
# Create a histogram
plt.figure(figsize=(10, 6))
plt.plot(us_companies['Year Joined'].value_counts().sort_index(), marker='o', linestyle='-')
plt.title('Histogram of US-based Unicorn Founding Years')
plt.xlabel('Founding Year')
plt.ylabel('Number of Unicorns')
plt.grid(axis='y')
plt.xticks(range(min(us_companies['Year Joined']), max(us_companies['Year Joined']) + 1))  # Adjust x-ticks for clarity

# Save plot to file
plt.savefig("output_data/CountryvsDateJoined/Histogram of US-Based Unicorn Founding Years")
plt.show()

# %%
china_companies = sortedMergedDF[sortedMergedDF['Country'] == 'China']

china_companies = pd.DataFrame(china_companies)

china_companies
# Out:
#                     Company 2022_Valuation 2023_Valuation  2024_Valuation  \
# 697                  Koudai          $1.40          $1.40            1.40
# 935        LinkSure Network             $1             $1            1.00
# 551              Apus Group          $1.73          $1.73            1.73
# 937                  BeiBei             $1             $1            1.00
# 18          DJI Innovations            $15            $15           15.00
# ..                      ...            ...            ...             ...
# 773  Greater Bay Technology          $1.26          $1.26            1.26
# 614             Gokin Solar          $1.51          $2.88            2.88
# 516               ROX Motor             $2             $2            2.00
# 734     Jaguar Microsystems          $1.34          $1.34            1.34
# 183              Zhiji Auto          $4.50            NaN             NaN
#
#     Date Joined Country       City                         Industry  \
# 697  2014-10-23   China    Beijing  E-commerce & direct-to-consumer
# 935  2015-01-01   China   Shanghai      Mobile & telecommunications
# 551  2015-01-16   China    Beijing      Mobile & telecommunications
# 937  2015-01-22   China   Hangzhou  E-commerce & direct-to-consumer
# 18   2015-01-23   China   Shenzhen                         Hardware
# ..          ...     ...        ...                              ...
# 773  2022-04-02   China  Guangzhou                         Hardware
# 614  2022-04-13   China     Zhuhai                            Other
# 516  2022-04-29   China   Shanghai            Auto & transportation
# 734  2022-06-23   China   Shenzhen                         Hardware
# 183  2022-08-01   China   Shanghai            Auto & transportation
#
#                                       Select Investors  Year Joined
# 697  New Enterprise Associates, Tiger Global manage...         2014
# 935                                                NaN         2015
# 551  Redpoint Ventures, QiMing Venture Partners, Ch...         2015
# 937  Banyan Capital, New Horizon Capital, IDG Capit...         2015
# 18                     Accel Partners, Sequoia Capital         2015
# ..                                                 ...          ...
# 773  Tencent Holdings, Utrust Venture Capital, GF X...         2022
# 614          IDG Capital, Puluo Capital, Midea Capital         2022
# 516  Sequoia Capital China, IDG Capital, Qiming Ven...         2022
# 734  Tencent Holdings, Glory Ventures, Shenzhen Cap...         2022
# 183                  Pudong VC, Zhiyou Venture Capital         2022
#
# [174 rows x 10 columns]

# %%
# Create a histogram
plt.figure(figsize=(10, 6))
plt.plot(china_companies['Year Joined'].value_counts().sort_index(), marker='o', linestyle='-')
plt.title('Histogram of China-based Unicorn Founding Years')
plt.xlabel('Founding Year')
plt.ylabel('Number of Unicorns')
plt.grid(axis='y')
plt.xticks(range(min(china_companies['Year Joined']), max(china_companies['Year Joined']) + 1))  # Adjust x-ticks for clarity

# Save plot to file
plt.savefig("output_data/CountryvsDateJoined/China Histogram")
plt.show()
