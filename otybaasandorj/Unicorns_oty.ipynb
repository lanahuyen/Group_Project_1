# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns

# %%
merged_path = Path("merged_df.csv", encoding="utf-8")
merged_file_df = pd.read_csv(merged_path)
merged_file_df.head()
# Out:
#    Unnamed: 0    Company 2022_Valuation 2023_Valuation  2024_Valuation  \
# 0           0  ByteDance           $140           $225           225.0
# 1           1     SpaceX           $127           $137           150.0
# 2           2      SHEIN           $100            $66            66.0
# 3           3     Stripe            $95            $50            65.0
# 4           4      Canva            $40            $40            25.4
#
#   Date Joined        Country           City                         Industry  \
# 0    4/7/2017          China        Beijing          Artificial intelligence
# 1   12/1/2012  United States      Hawthorne                            Other
# 2    7/3/2018          China       Shenzhen  E-commerce & direct-to-consumer
# 3   1/23/2014  United States  San Francisco                          Fintech
# 4    1/8/2018      Australia    Surry Hills     Internet software & services
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
merged_file_df.tail()
# Out:
#       Unnamed: 0              Company 2022_Valuation 2023_Valuation  \
# 1202        1202          LeadSquared             $1             $1
# 1203        1203            FourKites             $1             $1
# 1204        1204          VulcanForms             $1             $1
# 1205        1205          SingleStore             $1             $1
# 1206        1206  Unstoppable Domains             $1             $1
#
#       2024_Valuation Date Joined        Country           City  \
# 1202             1.0   6/21/2022          India      Bengaluru
# 1203             1.0   6/21/2022  United States        Chicago
# 1204             1.0    7/5/2022  United States     Burlington
# 1205             1.0   7/12/2022  United States  San Francisco
# 1206             1.0   7/27/2022  United States      Las Vegas
#
#                                  Industry  \
# 1202         Internet software & services
# 1203  Supply chain, logistics, & delivery
# 1204  Supply chain, logistics, & delivery
# 1205          Data management & analytics
# 1206         Internet software & services
#
#                                        Select Investors
# 1202  Gaja Capital Partners, Stakeboat Capital, West...
# 1203  Hyde Park Venture Partners, Bain Capital Ventu...
# 1204  Eclipse Ventures, D1 Capital Partners, Industr...
# 1205            Google Ventures, Accel, Data Collective
# 1206              Boost VC, Draper Associates, Gaingels

# %% [markdown]
# # Cleaning Data

# %%
clean_df = merged_file_df.rename(columns={"2022_Valuation": "2022 Valuation",
                                       "2023_Valuation": "2023 Valuation",
                                       "2024_Valuation": "2024 Valuation"})
clean_df.head()
# Out:
#    Unnamed: 0    Company 2022 Valuation 2023 Valuation  2024 Valuation  \
# 0           0  ByteDance           $140           $225           225.0
# 1           1     SpaceX           $127           $137           150.0
# 2           2      SHEIN           $100            $66            66.0
# 3           3     Stripe            $95            $50            65.0
# 4           4      Canva            $40            $40            25.4
#
#   Date Joined        Country           City                         Industry  \
# 0    4/7/2017          China        Beijing          Artificial intelligence
# 1   12/1/2012  United States      Hawthorne                            Other
# 2    7/3/2018          China       Shenzhen  E-commerce & direct-to-consumer
# 3   1/23/2014  United States  San Francisco                          Fintech
# 4    1/8/2018      Australia    Surry Hills     Internet software & services
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
clean_df.dtypes
# Out:
# Unnamed: 0            int64
# Company              object
# 2022 Valuation       object
# 2023 Valuation       object
# 2024 Valuation      float64
# Date Joined          object
# Country              object
# City                 object
# Industry             object
# Select Investors     object
# dtype: object

# %%
# clean_df = clean_df.replace({'\$': ''}, regex=True)
clean_df.head()
# Out:
#    Unnamed: 0    Company 2022 Valuation 2023 Valuation  2024 Valuation  \
# 0           0  ByteDance           $140           $225           225.0
# 1           1     SpaceX           $127           $137           150.0
# 2           2      SHEIN           $100            $66            66.0
# 3           3     Stripe            $95            $50            65.0
# 4           4      Canva            $40            $40            25.4
#
#   Date Joined        Country           City                         Industry  \
# 0    4/7/2017          China        Beijing          Artificial intelligence
# 1   12/1/2012  United States      Hawthorne                            Other
# 2    7/3/2018          China       Shenzhen  E-commerce & direct-to-consumer
# 3   1/23/2014  United States  San Francisco                          Fintech
# 4    1/8/2018      Australia    Surry Hills     Internet software & services
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
clean_df['2022 Valuation'] = clean_df['2022 Valuation'].str.replace('$', '').str.replace(',', '').astype(float)
clean_df['2023 Valuation'] = clean_df['2023 Valuation'].str.replace('$', '').str.replace(',', '').astype(float)
clean_df.dtypes
# Out:
# Unnamed: 0            int64
# Company              object
# 2022 Valuation      float64
# 2023 Valuation      float64
# 2024 Valuation      float64
# Date Joined          object
# Country              object
# City                 object
# Industry             object
# Select Investors     object
# dtype: object

# %%
clean_df.head()
# Out:
#    Unnamed: 0    Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 0           0  ByteDance           140.0           225.0           225.0
# 1           1     SpaceX           127.0           137.0           150.0
# 2           2      SHEIN           100.0            66.0            66.0
# 3           3     Stripe            95.0            50.0            65.0
# 4           4      Canva            40.0            40.0            25.4
#
#   Date Joined        Country           City                         Industry  \
# 0    4/7/2017          China        Beijing          Artificial intelligence
# 1   12/1/2012  United States      Hawthorne                            Other
# 2    7/3/2018          China       Shenzhen  E-commerce & direct-to-consumer
# 3   1/23/2014  United States  San Francisco                          Fintech
# 4    1/8/2018      Australia    Surry Hills     Internet software & services
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
valuations_df = clean_df[["Company", "2022 Valuation", "2023 Valuation", "2024 Valuation", "Country"]]
valuations_df.head()
# Out:
#      Company  2022 Valuation  2023 Valuation  2024 Valuation        Country
# 0  ByteDance           140.0           225.0           225.0          China
# 1     SpaceX           127.0           137.0           150.0  United States
# 2      SHEIN           100.0            66.0            66.0          China
# 3     Stripe            95.0            50.0            65.0  United States
# 4      Canva            40.0            40.0            25.4      Australia

# %%
valuations_df.describe()
# Out:
#        2022 Valuation  2023 Valuation  2024 Valuation
# count     1207.000000     1120.000000     1082.000000
# mean         3.270646        3.279437        3.354085
# std          7.591164        8.812529        9.433994
# min          1.000000        1.000000        1.000000
# 25%          1.100000        1.100000        1.100000
# 50%          1.600000        1.600000        1.635000
# 75%          3.000000        3.162500        3.200000
# max        140.000000      225.000000      225.000000

# %%
valuations_df.count()
# Out:
# Company           1207
# 2022 Valuation    1207
# 2023 Valuation    1120
# 2024 Valuation    1082
# Country           1207
# dtype: int64

# %% [markdown]
# # Growth

# %%
# Drop rows where valuation is NaN for years 2023 and 2024
active_df = clean_df.dropna(subset=["2023 Valuation", "2024 Valuation"], how='any')

# Optionally, you can reset index if needed
active_df = active_df.reset_index(drop=True)

# %%
active_df.count()
# Out:
# Unnamed: 0          1071
# Company             1071
# 2022 Valuation      1071
# 2023 Valuation      1071
# 2024 Valuation      1071
# Date Joined         1071
# Country             1071
# City                1071
# Industry            1071
# Select Investors    1054
# dtype: int64

# %%
# Find the active unicorn companies and the count
# active_valuations_df = valuations_df.dropna(how="any")
# active_valuations_df.count()

# %%
active_df.head()
# Out:
#    Unnamed: 0    Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 0           0  ByteDance           140.0           225.0           225.0
# 1           1     SpaceX           127.0           137.0           150.0
# 2           2      SHEIN           100.0            66.0            66.0
# 3           3     Stripe            95.0            50.0            65.0
# 4           4      Canva            40.0            40.0            25.4
#
#   Date Joined        Country           City                         Industry  \
# 0    4/7/2017          China        Beijing          Artificial intelligence
# 1   12/1/2012  United States      Hawthorne                            Other
# 2    7/3/2018          China       Shenzhen  E-commerce & direct-to-consumer
# 3   1/23/2014  United States  San Francisco                          Fintech
# 4    1/8/2018      Australia    Surry Hills     Internet software & services
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
active_df["Growth from 2022 to 2024"] = active_df["2024 Valuation"] - active_df["2022 Valuation"]
active_df["Growth from 2022 to 2024"] = active_df["Growth from 2022 to 2024"].astype("int").pd.set_option('display.float_format', '{:.2f}'.format)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xh/bpfw9ncn3299xqkmnvb8ld840000gn/T/ipykernel_10060/2966556625.py in ?()
#       1 active_df["Growth from 2022 to 2024"] = active_df["2024 Valuation"] - active_df["2022 Valuation"]
# ----> 2 active_df["Growth from 2022 to 2024"] = active_df["Growth from 2022 to 2024"].astype("int").pd.set_option('display.float_format', '{:.2f}'.format)
#
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'pd'

# %%
active_df.head()
# Out:
#    Unnamed: 0    Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 0           0  ByteDance           140.0           225.0           225.0
# 1           1     SpaceX           127.0           137.0           150.0
# 2           2      SHEIN           100.0            66.0            66.0
# 3           3     Stripe            95.0            50.0            65.0
# 4           4      Canva            40.0            40.0            25.4
#
#   Date Joined        Country           City                         Industry  \
# 0    4/7/2017          China        Beijing          Artificial intelligence
# 1   12/1/2012  United States      Hawthorne                            Other
# 2    7/3/2018          China       Shenzhen  E-commerce & direct-to-consumer
# 3   1/23/2014  United States  San Francisco                          Fintech
# 4    1/8/2018      Australia    Surry Hills     Internet software & services
#
#                                     Select Investors  Growth from 2022 to 2024
# 0  Sequoia Capital China, SIG Asia Investments, S...                      85.0
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...                      23.0
# 2  Tiger Global Management, Sequoia Capital China...                     -34.0
# 3        Khosla Ventures, LowercaseCapital, capitalG                     -30.0
# 4  Sequoia Capital China, Blackbird Ventures, Mat...                     -14.6

# %%
growth_df = active_df.sort_values("Growth from 2022 to 2024", ascending=False)
growth_df.head()
# Out:
#      Unnamed: 0     Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 0             0   ByteDance          140.00           225.0           225.0
# 299         333      OpenAI            2.92            29.0            80.0
# 1             1      SpaceX          127.00           137.0           150.0
# 206         235   VAST Data            3.70             3.7             9.1
# 6             7  Databricks           38.00            31.0            43.0
#
#     Date Joined        Country           City                     Industry  \
# 0      4/7/2017          China        Beijing      Artificial intelligence
# 299   7/22/2019  United States  San Francisco      Artificial intelligence
# 1     12/1/2012  United States      Hawthorne                        Other
# 206   4/16/2020  United States       New York  Data management & analytics
# 6      2/5/2019  United States  San Francisco  Data management & analytics
#
#                                       Select Investors  \
# 0    Sequoia Capital China, SIG Asia Investments, S...
# 299                                    Khosla Ventures
# 1    Founders Fund, Draper Fisher Jurvetson, Rothen...
# 206  Norwest Venture Partners, Goldman Sachs, Dell ...
# 6    Andreessen Horowitz, New Enterprise Associates...
#
#      Growth from 2022 to 2024
# 0                       85.00
# 299                     77.08
# 1                       23.00
# 206                      5.40
# 6                        5.00

# %%
new_growth_df = growth_df.reset_index(drop=True)
new_growth_df.head()
# Out:
#    Unnamed: 0     Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 0           0   ByteDance          140.00           225.0           225.0
# 1         333      OpenAI            2.92            29.0            80.0
# 2           1      SpaceX          127.00           137.0           150.0
# 3         235   VAST Data            3.70             3.7             9.1
# 4           7  Databricks           38.00            31.0            43.0
#
#   Date Joined        Country           City                     Industry  \
# 0    4/7/2017          China        Beijing      Artificial intelligence
# 1   7/22/2019  United States  San Francisco      Artificial intelligence
# 2   12/1/2012  United States      Hawthorne                        Other
# 3   4/16/2020  United States       New York  Data management & analytics
# 4    2/5/2019  United States  San Francisco  Data management & analytics
#
#                                     Select Investors  Growth from 2022 to 2024
# 0  Sequoia Capital China, SIG Asia Investments, S...                     85.00
# 1                                    Khosla Ventures                     77.08
# 2  Founders Fund, Draper Fisher Jurvetson, Rothen...                     23.00
# 3  Norwest Venture Partners, Goldman Sachs, Dell ...                      5.40
# 4  Andreessen Horowitz, New Enterprise Associates...                      5.00

# %%
new_growth_df.tail()
# Out:
#       Unnamed: 0       Company  2022 Valuation  2023 Valuation  \
# 1066          13        BYJU's            22.0            11.5
# 1067           4         Canva            40.0            40.0
# 1068           5  Checkout.com            40.0            11.0
# 1069           3        Stripe            95.0            50.0
# 1070           2         SHEIN           100.0            66.0
#
#       2024 Valuation Date Joined         Country           City  \
# 1066            11.5   7/25/2017           India      Bengaluru
# 1067            25.4    1/8/2018       Australia    Surry Hills
# 1068            11.0    5/2/2019  United Kingdom         London
# 1069            65.0   1/23/2014   United States  San Francisco
# 1070            66.0    7/3/2018           China       Shenzhen
#
#                              Industry  \
# 1066                           Edtech
# 1067     Internet software & services
# 1068                          Fintech
# 1069                          Fintech
# 1070  E-commerce & direct-to-consumer
#
#                                        Select Investors  \
# 1066  Tencent Holdings, Lightspeed India Partners, S...
# 1067  Sequoia Capital China, Blackbird Ventures, Mat...
# 1068  Tiger Global Management, Insight Partners, DST...
# 1069        Khosla Ventures, LowercaseCapital, capitalG
# 1070  Tiger Global Management, Sequoia Capital China...
#
#       Growth from 2022 to 2024
# 1066                     -10.5
# 1067                     -14.6
# 1068                     -29.0
# 1069                     -30.0
# 1070                     -34.0

# %%
new_growth_df["Growth from 2022 to 2024"].describe()
# Out:
# count    1071.000000
# mean        0.097152
# std         4.026649
# min       -34.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        85.000000
# Name: Growth from 2022 to 2024, dtype: float64

# %%
# Calculate growth for each year
new_growth_df['Growth 2022 to 2023'] = new_growth_df['2023 Valuation'] - new_growth_df['2022 Valuation']

# Aggregate growth by country for top 20 countries
country_growth_2022_2023 = new_growth_df.groupby('Country')['Growth 2022 to 2023'].sum().sort_values(ascending=False).head(10)

# Plotting
plt.figure(figsize=(12, 8))
barplot1 = sns.barplot(x=country_growth_2022_2023.values, y=country_growth_2022_2023.index, palette='pastel')
plt.title('Growth from 2022 to 2023 for Top 10 Countries', fontsize=16)
plt.xlabel('Growth', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Annotate bars with values inside the bars
for index, value in enumerate(country_growth_2022_2023):
    barplot1.text(value + 0.5, index, f'{value:.2f}', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.savefig("Images/growth_22-23_bar")
plt.show()

# %%
# Calculate growth for each year
new_growth_df['Growth 2023 to 2024'] = new_growth_df['2024 Valuation'] - new_growth_df['2023 Valuation']

# Aggregate growth by country for top 20 countries
country_growth_2023_2024 = new_growth_df.groupby('Country')['Growth 2023 to 2024'].sum().sort_values(ascending=False).head(10)

# Plotting
plt.figure(figsize=(12, 8))
barplot2 = sns.barplot(x=country_growth_2023_2024.values, y=country_growth_2023_2024.index, palette='pastel')
plt.title('Growth from 2023 to 2024 for Top 10 Countries', fontsize=16)
plt.xlabel('Growth', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Annotate bars with values inside the bars
for index, value in enumerate(country_growth_2023_2024):
    barplot2.text(value + 0.5, index, f'{value:.2f}', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.savefig("Images/growth_23-24_bar")
plt.show()

# %%
# Calculate total growth from 2022 to 2024
new_growth_df['Total Growth 2022 to 2024'] = new_growth_df['2024 Valuation'] - new_growth_df['2022 Valuation']

# Aggregate total growth by country for top 20 countries
country_total_growth = new_growth_df.groupby('Country')['Total Growth 2022 to 2024'].sum().sort_values(ascending=False).head(10)

# Plotting
plt.figure(figsize=(12, 8))
barplot_total = sns.barplot(x=country_total_growth.values, y=country_total_growth.index, palette='pastel')

plt.title('Total Growth from 2022 to 2024 for Top 10 Countries', fontsize=16)
plt.xlabel('Total Growth', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Annotate bars with values inside the bars
for index, value in enumerate(country_total_growth):
    barplot_total.text(value + 0.5, index, f'{value:.2f}', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.savefig("Images/total_growth_Bar")
plt.show()

# %%
# Calculate growth for each year
new_growth_df['Growth 2022 to 2023'] = new_growth_df['2023 Valuation'] - new_growth_df['2022 Valuation']

# Aggregate growth by country for top 20 countries
country_growth_2022_2023 = new_growth_df.groupby('Country')['Growth 2022 to 2023'].sum().sort_values(ascending=False).head(20)

# Create scatter plot for growth from 2022 to 2023
plt.figure(figsize=(12, 8))
sns.scatterplot(x=country_growth_2022_2023.values, y=country_growth_2022_2023.index, s=100, palette='viridis')
plt.title('Growth from 2022 to 2023 for Top 20 Countries', fontsize=16)
plt.xlabel('Growth from 2022 to 2023', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/xh/bpfw9ncn3299xqkmnvb8ld840000gn/T/ipykernel_10060/3469966333.py:9: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=country_growth_2022_2023.values, y=country_growth_2022_2023.index, s=100, palette='viridis')

# %%
# Example data preparation (replace with your actual data)
# Group by country and aggregate sum of valuations for 2022, 2023, and 2024
country_sum_valuations = new_growth_df.groupby('Country')[['2022 Valuation', '2023 Valuation', '2024 Valuation']].sum()

# Select top 20 countries by sum of valuations
top_20_countries = country_sum_valuations.sum(axis=1).nlargest(10).index

# Filter the original data to include only the top 20 countries
filtered_data = new_growth_df[new_growth_df['Country'].isin(top_20_countries)]

# Group by country and aggregate sum of valuations for the top 20 countries
country_valuations_top_20 = filtered_data.groupby('Country')[['2022 Valuation', '2023 Valuation', '2024 Valuation']].sum()

# Plotting
plt.figure(figsize=(12, 8))

# Plot each country's sum of valuations as a line
for country in country_valuations_top_20.index:
    plt.plot(country_valuations_top_20.columns, country_valuations_top_20.loc[country], marker='o', label=country)

# Customize labels, title, and ticks
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sum of Valuation', fontsize=14)
plt.title('Sum of Valuations for Top 10 Countries (2022-2024)', fontsize=16)
plt.xticks(country_valuations_top_20.columns)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust legend position

plt.grid(True)  # Add grid lines for better readability

plt.tight_layout()
plt.savefig("Images/2022-23-24graph")
plt.show()

# %%
# Find rows with any NaN values
empty_valuations_df = valuations_df[valuations_df.isna().any(axis=1)]

print("\nRows with empty values:")
empty_valuations_df.head()
# Out:
# Rows with empty values:
#                    Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 6                Instacart            39.0            12.0             NaN
# 10                     FTX            32.0             NaN             NaN
# 15             J&T Express            20.0            20.0             NaN
# 20                  goPuff            15.0             NaN             NaN
# 33  Biosplice Therapeutics            12.0             NaN             NaN
#
#           Country
# 6   United States
# 10        Bahamas
# 15      Indonesia
# 20  United States
# 33  United States

# %%
empty_valuations_df.count()
# Out:
# Company           136
# 2022 Valuation    136
# 2023 Valuation     49
# 2024 Valuation     11
# Country           136
# dtype: int64

# %% [markdown]
# # Country

# %%
# Create a crosstab to see the frequency of each Industry in each Country
country_industry_crosstab = pd.crosstab(new_growth_df['Country'], new_growth_df['Industry'])

country_industry_crosstab.head()
# Out:
# Industry   500 Global, Rakuten Ventures, Golden Gate Ventures  \
# Country
# Argentina                                                  0
# Australia                                                  0
# Austria                                                    0
# Belgium                                                    0
# Bermuda                                                    0
#
# Industry   Andreessen Horowitz, DST Global, IDG Capital  \
# Country
# Argentina                                             0
# Australia                                             0
# Austria                                               0
# Belgium                                               0
# Bermuda                                               0
#
# Industry   Artificial Intelligence  Artificial intelligence  \
# Country
# Argentina                        0                        0
# Australia                        0                        0
# Austria                          0                        0
# Belgium                          0                        0
# Bermuda                          0                        1
#
# Industry   Auto & transportation  \
# Country
# Argentina                      0
# Australia                      0
# Austria                        0
# Belgium                        0
# Bermuda                        0
#
# Industry   B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution  \
# Country
# Argentina                                                  0
# Australia                                                  0
# Austria                                                    0
# Belgium                                                    0
# Bermuda                                                    0
#
# Industry   Consumer & retail  Cybersecurity  Data management & analytics  \
# Country
# Argentina                  0              0                            0
# Australia                  0              0                            0
# Austria                    0              0                            0
# Belgium                    0              0                            1
# Bermuda                    0              0                            0
#
# Industry   Dragonfly Captial, Qiming Venture Partners, DST Global  ...  Other  \
# Country                                                            ...
# Argentina                                                  0       ...      0
# Australia                                                  0       ...      0
# Austria                                                    0       ...      0
# Belgium                                                    0       ...      0
# Bermuda                                                    0       ...      0
#
# Industry   Sequoia Capital China, ING, Alibaba Entrepreneurs Fund  \
# Country
# Argentina                                                  0
# Australia                                                  0
# Austria                                                    0
# Belgium                                                    0
# Bermuda                                                    0
#
# Industry   Sequoia Capital China, Shunwei Capital Partners, Qualgro  \
# Country
# Argentina                                                  0
# Australia                                                  0
# Austria                                                    0
# Belgium                                                    0
# Bermuda                                                    0
#
# Industry   SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures  \
# Country
# Argentina                                                  0
# Australia                                                  0
# Austria                                                    0
# Belgium                                                    0
# Bermuda                                                    0
#
# Industry   Supply chain, logistics, & delivery  \
# Country
# Argentina                                    0
# Australia                                    0
# Austria                                      0
# Belgium                                      0
# Bermuda                                      0
#
# Industry   Temasek, Guggenheim Investments, Qatar Investment Authority  \
# Country
# Argentina                                                  0
# Australia                                                  0
# Austria                                                    0
# Belgium                                                    0
# Bermuda                                                    0
#
# Industry   Tiger Global Management, Tiger Brokers, DCM Ventures  Travel  \
# Country
# Argentina                                                  0          0
# Australia                                                  0          0
# Austria                                                    0          0
# Belgium                                                    0          0
# Bermuda                                                    0          0
#
# Industry   Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures  \
# Country
# Argentina                                                  0
# Australia                                                  0
# Austria                                                    0
# Belgium                                                    0
# Bermuda                                                    0
#
# Industry   Vision Plus Capital, GSR Ventures, ZhenFund
# Country
# Argentina                                            0
# Australia                                            0
# Austria                                              0
# Belgium                                              0
# Bermuda                                              0
#
# [5 rows x 33 columns]

# %%
# Step 1: Identify the top 10 countries and top 5 industries
top_countries = new_growth_df['Country'].value_counts().nlargest(10).index
top_industries = new_growth_df['Industry'].value_counts().nlargest(5).index

# Step 2: Filter the dataframe to include only the top countries and industries
filtered_df = new_growth_df[new_growth_df['Country'].isin(top_countries) & new_growth_df['Industry'].isin(top_industries)]

# Step 3: Create a crosstab for the filtered data
filtered_crosstab = pd.crosstab(filtered_df['Country'], filtered_df['Industry'])

# Step 4: Create a stacked bar chart
filtered_crosstab.plot(kind='bar', stacked=True, figsize=(15, 10), colormap='tab20')
plt.title('Top 5 Industries')
plt.xlabel('Country')
plt.ylabel('Count')
plt.legend(title='Industry', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Step 1: Filter out the United States
filtered_df_no_us = new_growth_df[new_growth_df['Country'] != 'United States']

# Step 2: Identify the top 10 countries (excluding the United States) and top 5 industries
top_countries_no_us = filtered_df_no_us['Country'].value_counts().nlargest(10).index
top_industries = new_growth_df['Industry'].value_counts().nlargest(5).index

# Step 3: Filter the dataframe to include only the top countries and industries
filtered_df_no_us = filtered_df_no_us[filtered_df_no_us['Country'].isin(top_countries_no_us) & filtered_df_no_us['Industry'].isin(top_industries)]

# Step 4: Create a crosstab for the filtered data
filtered_crosstab_no_us = pd.crosstab(filtered_df_no_us['Country'], filtered_df_no_us['Industry'])

# Step 5: Calculate the total count for each country
totals = filtered_crosstab_no_us.sum(axis=1)

ax = filtered_crosstab_no_us.plot(kind='bar', stacked=True, figsize=(15, 10))
plt.title('Top 5 Industries by Top 10 Countries (Excluding United States)')
plt.xlabel('Country')
plt.ylabel('Count')
plt.legend(title='Industry', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)  # Slant x-axis labels by 45 degrees
plt.tight_layout()

# Add total count labels at the top of each bar
for i, total in enumerate(totals):
    ax.text(i, total + 1, str(total), ha='center', va='bottom')

plt.show()

# %%
grouped_df = new_growth_df.groupby(['Country', 'Industry']).size().reset_index(name='count')

# Displaying the grouped dataframe
grouped_df
# Out:
#            Country                             Industry  count
# 0        Argentina                              Fintech      1
# 1        Australia      E-commerce & direct-to-consumer      1
# 2        Australia                              Fintech      2
# 3        Australia         Internet software & services      5
# 4          Austria                               Edtech      1
# ..             ...                                  ...    ...
# 204  United States          Mobile & telecommunications     13
# 205  United States                                Other     27
# 206  United States  Supply chain, logistics, & delivery     21
# 207        Vietnam                              Fintech      1
# 208        Vietnam         Internet software & services      1
#
# [209 rows x 3 columns]

# %%
pivot_table = grouped_df.pivot(index='Country', columns='Industry', values='count')

plt.figure(figsize=(12, 8))
pivot_table.plot(kind='bar', stacked=True, cmap='tab20')
plt.title('Composition of Companies by Country and Industry')
plt.xlabel('Country')
plt.ylabel('Number of Companies')
plt.xticks(rotation=45)
plt.legend(title='Industry', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/xh/bpfw9ncn3299xqkmnvb8ld840000gn/T/ipykernel_10060/1974802844.py:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Group and count companies by country
country_counts = grouped_df['Country'].value_counts()

# Select top 10 countries based on the count of companies
top_10_countries = country_counts.head(10).index

# Filter grouped_df to include only the top 10 countries
filtered_df_countries = grouped_df[grouped_df['Country'].isin(top_10_countries)]

# Group and count companies by industry
industry_counts = grouped_df['Industry'].value_counts()

# Select top 10 industries based on the count of companies
top_10_industries = industry_counts.head(10).index

# Filter grouped_df to include only the top 10 industries
filtered_df_industries = grouped_df[grouped_df['Industry'].isin(top_10_industries)]

# Create pivot tables
pivot_table_countries = filtered_df_countries.pivot_table(index='Country', columns='Industry', values='count', aggfunc='sum')
pivot_table_industries = filtered_df_industries.pivot_table(index='Industry', columns='Country', values='count', aggfunc='sum')

# Plotting
plt.figure(figsize=(12, 8))

# Plot for top 10 countries
ax1 = plt.subplot(211)
pivot_table_countries.plot(kind='bar', stacked=True, cmap='tab20', ax=ax1)
ax1.set_title('Composition of Companies by Top 10 Countries and Industries')
ax1.set_xlabel('Country')
ax1.set_ylabel('Number of Companies')
ax1.legend(title='Industry', bbox_to_anchor=(1.05, 1), loc='upper left')
ax1.tick_params(axis='x', rotation=45, ha='right')

# Plot for top 10 industries
ax2 = plt.subplot(212)
pivot_table_industries.plot(kind='bar', stacked=True, cmap='tab20', ax=ax2)
ax2.set_xlabel('Industry')
ax2.set_ylabel('Number of Companies')
ax2.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
ax2.tick_params(axis='x', rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[300], line 33
#      31 ax1.set_ylabel('Number of Companies')
#      32 ax1.legend(title='Industry', bbox_to_anchor=(1.05, 1), loc='upper left')
# ---> 33 ax1.tick_params(axis='x', rotation=45, ha='right')
#      35 # Plot for top 10 industries
#      36 ax2 = plt.subplot(212)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axes/_base.py:3436, in _AxesBase.tick_params(self, axis, **kwargs)
#    3434     xkw.pop('labelleft', None)
#    3435     xkw.pop('labelright', None)
# -> 3436     self.xaxis.set_tick_params(**xkw)
#    3437 if axis in ['y', 'both']:
#    3438     ykw = dict(kwargs)
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axis.py:983, in Axis.set_tick_params(self, which, reset, **kwargs)
#     970 """
#     971 Set appearance parameters for ticks, ticklabels, and gridlines.
#     972
#    (...)
#     980     gridlines.
#     981 """
#     982 _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 983 kwtrans = self._translate_tick_params(kwargs)
#     985 # the kwargs are stored in self._major/minor_tick_kw so that any
#     986 # future new ticks will automatically get them
#     987 if reset:
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axis.py:1127, in Axis._translate_tick_params(kw, reverse)
#    1125 for key in kw_:
#    1126     if key not in allowed_keys:
# -> 1127         raise ValueError(
#    1128             "keyword %s is not recognized; valid keywords are %s"
#    1129             % (key, allowed_keys))
#    1130 kwtrans.update(kw_)
#    1131 return kwtrans
#
# ValueError: keyword ha is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'labelfontfamily', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']

# %%
new_growth_df["Country"].value_counts().head(10)
# Out:
# Country
# United States     581
# China             149
# India              59
# United Kingdom     43
# Germany            26
# France             23
# Israel             18
# Canada             18
# Brazil             16
# Singapore          13
# Name: count, dtype: int64

# %%
new_growth_df["Country"].value_counts().tail()
# Out:
# Country
# Nigeria        1
# Seychelles     1
# Philippines    1
# Italy          1
# Argentina      1
# Name: count, dtype: int64

# %%
# country_industry_df = new_growth_df[["Company", "Country", "Industry"]]
# country_industry_df.head()

# %%
usa_df = new_growth_df.loc[country_industry_df["Country"] == "United States",:]
china_df = new_growth_df.loc[country_industry_df["Country"] == "China",:]
india_df = new_growth_df.loc[country_industry_df["Country"] == "India",:]

# %%
usa_df.head()
# Out:
#    Unnamed: 0     Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 1         333      OpenAI            2.92            29.0            80.0
# 2           1      SpaceX          127.00           137.0           150.0
# 3         235   VAST Data            3.70             3.7             9.1
# 4           7  Databricks           38.00            31.0            43.0
# 6          11    Fanatics           27.00            31.0            31.0
#
#   Date Joined        Country           City                         Industry  \
# 1   7/22/2019  United States  San Francisco          Artificial intelligence
# 2   12/1/2012  United States      Hawthorne                            Other
# 3   4/16/2020  United States       New York      Data management & analytics
# 4    2/5/2019  United States  San Francisco      Data management & analytics
# 6    6/6/2012  United States   Jacksonville  E-commerce & direct-to-consumer
#
#                                     Select Investors  Growth from 2022 to 2024
# 1                                    Khosla Ventures                     77.08
# 2  Founders Fund, Draper Fisher Jurvetson, Rothen...                     23.00
# 3  Norwest Venture Partners, Goldman Sachs, Dell ...                      5.40
# 4  Andreessen Horowitz, New Enterprise Associates...                      5.00
# 6  SoftBank Group, Andreessen Horowitz, Temasek H...                      4.00

# %%
china_df.head()
# Out:
#     Unnamed: 0      Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 0            0    ByteDance          140.00          225.00          225.00
# 28         614  Gokin Solar            1.51            2.88            2.88
# 62         794  GalaxySpace            1.22            1.58            1.58
# 70         808        Aibee            1.00            1.20            1.20
# 77         789      Enflame            1.24            1.24            1.24
#
#    Date Joined Country      City                     Industry  \
# 0     4/7/2017   China   Beijing      Artificial intelligence
# 28   4/13/2022   China    Zhuhai                        Other
# 62  11/17/2020   China   Beijing  Mobile & telecommunications
# 70   4/13/2021   China   Beijing      Artificial intelligence
# 77    1/5/2021   China  Shanghai                     Hardware
#
#                                      Select Investors  \
# 0   Sequoia Capital China, SIG Asia Investments, S...
# 28          IDG Capital, Puluo Capital, Midea Capital
# 62  Shunwei Capital Partners, 5Y Capital, Legend C...
# 70  Sequoia Capital China, Lenovo Capital and Incu...
# 77  Tencent Holdings, Delta Capital, Redpoint Vent...
#
#     Growth from 2022 to 2024
# 0                      85.00
# 28                      1.37
# 62                      0.36
# 70                      0.20
# 77                      0.00

# %%
india_df.head()
# Out:
#     Unnamed: 0                Company  2022 Valuation  2023 Valuation  \
# 15         199                   CRED            4.01             6.4
# 21         437               FirstCry            2.10             2.1
# 53         156  Ola Electric Mobility            5.00             6.0
# 61        1175                  Amagi            1.00             1.4
# 67         834             Xpressbees            1.20             1.4
#
#     2024 Valuation Date Joined Country       City  \
# 15            6.40    4/6/2021   India  Bengaluru
# 21            3.75    2/7/2020   India       Pune
# 53            5.50    7/2/2019   India  Bengaluru
# 61            1.40   3/16/2022   India  Bengaluru
# 67            1.40    2/9/2022   India       Pune
#
#                                Industry  \
# 15                              Fintech
# 21      E-commerce & direct-to-consumer
# 53                Auto & transportation
# 61         Internet software & services
# 67  Supply chain, logistics, & delivery
#
#                                      Select Investors  \
# 15  Tiger Global Management, DST Global, Sequoia C...
# 21  SoftBank Group, SAIF Partners India, Valiant C...
# 53  SoftBank Group, Tiger Global Management, Matri...
# 61          Mayfield, Accel, Norwest Venture Partners
# 67   Norwest Venture Partners, Investcorp, Blackstone
#
#     Growth from 2022 to 2024
# 15                      2.39
# 21                      1.65
# 53                      0.50
# 61                      0.40
# 67                      0.20

# %% [markdown]
# # Industry and Country

# %%
clean_df["Industry"].value_counts().head()
# Out:
# Industry
# Fintech                            245
# Internet software & services       227
# E-commerce & direct-to-consumer    106
# Health                              94
# Artificial intelligence             74
# Name: count, dtype: int64

# %%
len(clean_df["Industry"])
# Out:
# 1207

# %%
clean_df.count()
# Out:
# Unnamed: 0          1207
# Company             1207
# 2022 Valuation      1207
# 2023 Valuation      1120
# 2024 Valuation      1082
# Date Joined         1207
# Country             1207
# City                1207
# Industry            1207
# Select Investors    1189
# dtype: int64

# %% [markdown]
# # Select Investors

# %%
unique = clean_df["Select Investors"].nunique()
total_investors = clean_df["Select Investors"].count()

print(unique)
print(f"There are {unique} number of unique select investors.")

print(total_investors)
print(f"There are a total of {total_investors} select investors.")
# Out:
# 1152
# There are 1152 number of unique select investors.
# 1189
# There are a total of 1189 select investors.

# %%
clean_df["Select Investors"].head()
# Out:
# 0    Sequoia Capital China, SIG Asia Investments, S...
# 1    Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2    Tiger Global Management, Sequoia Capital China...
# 3          Khosla Ventures, LowercaseCapital, capitalG
# 4    Sequoia Capital China, Blackbird Ventures, Mat...
# Name: Select Investors, dtype: object

# %%
# Split select_investors into separate columns
invest_df = clean_df['Select Investors'].str.split(', ', expand=True)

# Concatenate the new columns with the original DataFrame
new_investor_df = pd.concat([clean_df, invest_df], axis=1)

new_investor_df.head()
# Out:
#    Unnamed: 0    Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 0           0  ByteDance           140.0           225.0           225.0
# 1           1     SpaceX           127.0           137.0           150.0
# 2           2      SHEIN           100.0            66.0            66.0
# 3           3     Stripe            95.0            50.0            65.0
# 4           4      Canva            40.0            40.0            25.4
#
#   Date Joined        Country           City                         Industry  \
# 0    4/7/2017          China        Beijing          Artificial intelligence
# 1   12/1/2012  United States      Hawthorne                            Other
# 2    7/3/2018          China       Shenzhen  E-commerce & direct-to-consumer
# 3   1/23/2014  United States  San Francisco                          Fintech
# 4    1/8/2018      Australia    Surry Hills     Internet software & services
#
#                                     Select Investors                        0  \
# 0  Sequoia Capital China, SIG Asia Investments, S...    Sequoia Capital China
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...            Founders Fund
# 2  Tiger Global Management, Sequoia Capital China...  Tiger Global Management
# 3        Khosla Ventures, LowercaseCapital, capitalG          Khosla Ventures
# 4  Sequoia Capital China, Blackbird Ventures, Mat...    Sequoia Capital China
#
#                          1                         2               3
# 0     SIG Asia Investments                Sina Weibo  Softbank Group
# 1  Draper Fisher Jurvetson       Rothenberg Ventures            None
# 2    Sequoia Capital China  Shunwei Capital Partners            None
# 3         LowercaseCapital                  capitalG            None
# 4       Blackbird Ventures           Matrix Partners            None

# %%
# Make a new DataFrame of just all investors
investors_df = new_investor_df.iloc[:, 10:14]
investors_df.head()
# Out:
#                          0                        1                         2  \
# 0    Sequoia Capital China     SIG Asia Investments                Sina Weibo
# 1            Founders Fund  Draper Fisher Jurvetson       Rothenberg Ventures
# 2  Tiger Global Management    Sequoia Capital China  Shunwei Capital Partners
# 3          Khosla Ventures         LowercaseCapital                  capitalG
# 4    Sequoia Capital China       Blackbird Ventures           Matrix Partners
#
#                 3
# 0  Softbank Group
# 1            None
# 2            None
# 3            None
# 4            None

# %%
investors_df.count()
# Out:
# 0    1189
# 1    1136
# 2    1038
# 3       7
# dtype: int64

# %%
# Checking for different capilization that may throw off our data (very slight but it did)
investors_df[0] = investors_df[0].str.lower()
investors_df[1] = investors_df[1].str.lower()
investors_df[2] = investors_df[2].str.lower()
investors_df[3] = investors_df[3].str.lower()

# %%
# Combine all investor columns into a single Series
investors_series = pd.concat([investors_df[0], investors_df[1], investors_df[2], investors_df[3]], ignore_index=True)

# Find the most common investor
most_frequent_investor = investors_series.value_counts()
print(most_frequent_investor)

most_frequent_investor = investors_series.value_counts().idxmax().title()
print(f"The most frequent investor is: {most_frequent_investor}")
# Out:
# accel                        62
# tiger global management      58
# andreessen horowitz          58
# insight partners             53
# sequoia capital              52
#                              ..
# china renaissance             1
# new leaf venture partners     1
# gron ventures                 1
# webb investment network       1
# nirvana venture advisors      1
# Name: count, Length: 1348, dtype: int64
# The most frequent investor is: Accel

# %%
most_frequent_investor.title()
# Out:
# 'Accel'

# %%
# Convert to string to handle potential None or NaN values
investors_series = investors_series.astype(str)

# Filter out 'None', 'nan', and 'none' values
investors_series = investors_series[~investors_series.isin(['none', 'nan', 'None'])]

# Find the most common investor
most_frequent_investor = investors_series.value_counts().head(25)

# Capitalize each word in index labels and most common investor label
most_frequent_investor.index = most_frequent_investor.index.str.title()

# Plotting
plt.figure(figsize=(12, 6))  # Increase figure width
barplot = sns.barplot(x=most_frequent_investor.index, y=most_frequent_investor.values, palette="pastel")

# Annotate bars with values inside the bars (capitalized)
for index, value in enumerate(most_frequent_investor):
    barplot.text(index, value + 1, str(value), ha='center', va='bottom', fontsize=10)

# Highlighting the most common investor
plt.axhline(y=most_frequent_investor.max(), color='red', linestyle='--', linewidth=2,
            label=f'Most Frequent Investor: {most_frequent_investor.idxmax().title()}')

plt.title('Investor Frequency', fontdict={'fontsize': 18})  # Title font
plt.xlabel('Investor')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Adjust rotation and horizontal alignment
plt.legend()
plt.tight_layout()

plt.savefig("Images/investor_frequency.png")
plt.show()

# %%
# Example of finding companies invested by "Accel"
companies_by_accel = new_growth_df.loc[new_growth_df['Select Investors'].str.contains('Accel', na=False)]

# Displaying the results
companies_by_accel.head()
# Out:
#     Unnamed: 0    Company  2022 Valuation  2023 Valuation  2024 Valuation  \
# 30        1015     Skydio            1.00            2.20            2.20
# 61        1175      Amagi            1.00            1.40            1.40
# 73         375    Zetwerk            2.68            2.70            2.80
# 76        1071  BlackBuck            1.00            1.02            1.02
# 85         805     Public            1.20            1.20            1.20
#
#    Date Joined        Country          City  \
# 30   2/25/2021  United States  Redwood City
# 61   3/16/2022          India     Bengaluru
# 73   8/20/2021          India     Bengaluru
# 76   7/22/2021          India     Bengaluru
# 85   2/17/2021  United States      New York
#
#                                Industry  \
# 30  Supply chain, logistics, & delivery
# 61         Internet software & services
# 73         Internet software & services
# 76  Supply chain, logistics, & delivery
# 85                              Fintech
#
#                                      Select Investors  \
# 30  Andreessen Horowitz, Andreessen Horowitz, Inst...
# 61          Mayfield, Accel, Norwest Venture Partners
# 73          Sequoia Capital India, Kae Capital, Accel
# 76  Accel, Sands Capital, International Finance Co...
# 85                 Accel, Greycroft, Advancit Capital
#
#     Growth from 2022 to 2024  Growth 2022 to 2023  Growth 2023 to 2024  \
# 30                      1.20                 1.20                  0.0
# 61                      0.40                 0.40                  0.0
# 73                      0.12                 0.02                  0.1
# 76                      0.02                 0.02                  0.0
# 85                      0.00                 0.00                  0.0
#
#     Total Growth 2022 to 2024
# 30                       1.20
# 61                       0.40
# 73                       0.12
# 76                       0.02
# 85                       0.00

# %%
accel_investments = new_growth_df[new_growth_df['Select Investors'].str.contains('Accel', na=False)]

# Count investments by industry
accel_industry_counts = accel_investments['Industry'].value_counts()

# Sort industries by investment counts in descending order
sorted_industries = accel_industry_counts.sort_values(ascending=False)

sorted_industries
# Out:
# Industry
# Internet software & services           17
# Fintech                                15
# Supply chain, logistics, & delivery     5
# Cybersecurity                           5
# E-commerce & direct-to-consumer         5
# Artificial intelligence                 4
# Data management & analytics             3
# Other                                   2
# Edtech                                  2
# Mobile & telecommunications             1
# Hardware                                1
# Health                                  1
# Auto & transportation                   1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=sorted_industries.values, y=sorted_industries.index, palette='pastel')

plt.title('Industries Invested in by Accel', fontsize=16)
plt.xlabel('Number of Investments', fontsize=14)
plt.ylabel('Industry', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
